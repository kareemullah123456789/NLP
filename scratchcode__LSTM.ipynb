# %% [markdown]
# <a href="https://colab.research.google.com/github/kareemullah123456789/NLP/blob/main/scratchcode__LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
This is a batched LSTM forward and backward pass
"""
import numpy as np
import code

class LSTM:

  @staticmethod
  def init(input_size, hidden_size, fancy_forget_bias_init = 3):
    """
    Initialize parameters of the LSTM (both weights and biases in one matrix)
    One might way to have a positive fancy_forget_bias_init number (e.g. maybe even up to 5, in some papers)
    """
    # +1 for the biases, which will be the first row of WLSTM
    WLSTM = np.random.randn(input_size + hidden_size + 1, 4 * hidden_size) / np.sqrt(input_size + hidden_size)
    WLSTM[0,:] = 0 # initialize biases to zero
    if fancy_forget_bias_init != 0:
      # forget gates get little bit negative bias initially to encourage them to be turned off
      # remember that due to Xavier initialization above, the raw output activations from gates before
      # nonlinearity are zero mean and on order of standard deviation ~1
      WLSTM[0,hidden_size:2*hidden_size] = fancy_forget_bias_init
    return WLSTM

  @staticmethod
  def forward(X, WLSTM, c0 = None, h0 = None):
    """
    X should be of shape (n,b,input_size), where n = length of sequence, b = batch size
    """
    n,b,input_size = X.shape
    d = WLSTM.shape[1]/4 # hidden size
    if c0 is None: c0 = np.zeros((b,d))
    if h0 is None: h0 = np.zeros((b,d))

    # Perform the LSTM forward pass with X as the input
    xphpb = WLSTM.shape[0] # x plus h plus bias, lol
    Hin = np.zeros((n, b, xphpb)) # input [1, xt, ht-1] to each tick of the LSTM
    Hout = np.zeros((n, b, d)) # hidden representation of the LSTM (gated cell content)
    IFOG = np.zeros((n, b, d * 4)) # input, forget, output, gate (IFOG)
    IFOGf = np.zeros((n, b, d * 4)) # after nonlinearity
    C = np.zeros((n, b, d)) # cell content
    Ct = np.zeros((n, b, d)) # tanh of cell content
    for t in xrange(n):
      # concat [x,h] as input to the LSTM
      prevh = Hout[t-1] if t > 0 else h0
      Hin[t,:,0] = 1 # bias
      Hin[t,:,1:input_size+1] = X[t]
      Hin[t,:,input_size+1:] = prevh
      # compute all gate activations. dots: (most work is this line)
      IFOG[t] = Hin[t].dot(WLSTM)
      # non-linearities
      IFOGf[t,:,:3*d] = 1.0/(1.0+np.exp(-IFOG[t,:,:3*d])) # sigmoids; these are the gates
      IFOGf[t,:,3*d:] = np.tanh(IFOG[t,:,3*d:]) # tanh
      # compute the cell activation
      prevc = C[t-1] if t > 0 else c0
      C[t] = IFOGf[t,:,:d] * IFOGf[t,:,3*d:] + IFOGf[t,:,d:2*d] * prevc
      Ct[t] = np.tanh(C[t])
      Hout[t] = IFOGf[t,:,2*d:3*d] * Ct[t]

    cache = {}
    cache['WLSTM'] = WLSTM
    cache['Hout'] = Hout
    cache['IFOGf'] = IFOGf
    cache['IFOG'] = IFOG
    cache['C'] = C
    cache['Ct'] = Ct
    cache['Hin'] = Hin
    cache['c0'] = c0
    cache['h0'] = h0

    # return C[t], as well so we can continue LSTM with prev state init if needed
    return Hout, C[t], Hout[t], cache

  @staticmethod
  def backward(dHout_in, cache, dcn = None, dhn = None):

    WLSTM = cache['WLSTM']
    Hout = cache['Hout']
    IFOGf = cache['IFOGf']
    IFOG = cache['IFOG']
    C = cache['C']
    Ct = cache['Ct']
    Hin = cache['Hin']
    c0 = cache['c0']
    h0 = cache['h0']
    n,b,d = Hout.shape
    input_size = WLSTM.shape[0] - d - 1 # -1 due to bias

    # backprop the LSTM
    dIFOG = np.zeros(IFOG.shape)
    dIFOGf = np.zeros(IFOGf.shape)
    dWLSTM = np.zeros(WLSTM.shape)
    dHin = np.zeros(Hin.shape)
    dC = np.zeros(C.shape)
    dX = np.zeros((n,b,input_size))
    dh0 = np.zeros((b, d))
    dc0 = np.zeros((b, d))
    dHout = dHout_in.copy() # make a copy so we don't have any funny side effects
    if dcn is not None: dC[n-1] += dcn.copy() # carry over gradients from later
    if dhn is not None: dHout[n-1] += dhn.copy()
    for t in reversed(xrange(n)):

      tanhCt = Ct[t]
      dIFOGf[t,:,2*d:3*d] = tanhCt * dHout[t]
      # backprop tanh non-linearity first then continue backprop
      dC[t] += (1-tanhCt**2) * (IFOGf[t,:,2*d:3*d] * dHout[t])

      if t > 0:
        dIFOGf[t,:,d:2*d] = C[t-1] * dC[t]
        dC[t-1] += IFOGf[t,:,d:2*d] * dC[t]
      else:
        dIFOGf[t,:,d:2*d] = c0 * dC[t]
        dc0 = IFOGf[t,:,d:2*d] * dC[t]
      dIFOGf[t,:,:d] = IFOGf[t,:,3*d:] * dC[t]
      dIFOGf[t,:,3*d:] = IFOGf[t,:,:d] * dC[t]

      # backprop activation functions
      dIFOG[t,:,3*d:] = (1 - IFOGf[t,:,3*d:] ** 2) * dIFOGf[t,:,3*d:]
      y = IFOGf[t,:,:3*d]
      dIFOG[t,:,:3*d] = (y*(1.0-y)) * dIFOGf[t,:,:3*d]

      # backprop matrix multiply
      dWLSTM += np.dot(Hin[t].transpose(), dIFOG[t])
      dHin[t] = dIFOG[t].dot(WLSTM.transpose())

      # backprop the identity transforms into Hin
      dX[t] = dHin[t,:,1:input_size+1]
      if t > 0:
        dHout[t-1,:] += dHin[t,:,input_size+1:]
      else:
        dh0 += dHin[t,:,input_size+1:]

    return dX, dWLSTM, dc0, dh0



# -------------------
# TEST CASES
# -------------------



def checkSequentialMatchesBatch():
  """ check LSTM I/O forward/backward interactions """

  n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
  input_size = 10
  WLSTM = LSTM.init(input_size, d) # input size, hidden size
  X = np.random.randn(n,b,input_size)
  h0 = np.random.randn(b,d)
  c0 = np.random.randn(b,d)

  # sequential forward
  cprev = c0
  hprev = h0
  caches = [{} for t in xrange(n)]
  Hcat = np.zeros((n,b,d))
  for t in xrange(n):
    xt = X[t:t+1]
    _, cprev, hprev, cache = LSTM.forward(xt, WLSTM, cprev, hprev)
    caches[t] = cache
    Hcat[t] = hprev

  # sanity check: perform batch forward to check that we get the same thing
  H, _, _, batch_cache = LSTM.forward(X, WLSTM, c0, h0)
  assert np.allclose(H, Hcat), 'Sequential and Batch forward don''t match!'

  # eval loss
  wrand = np.random.randn(*Hcat.shape)
  loss = np.sum(Hcat * wrand)
  dH = wrand

  # get the batched version gradients
  BdX, BdWLSTM, Bdc0, Bdh0 = LSTM.backward(dH, batch_cache)

  # now perform sequential backward
  dX = np.zeros_like(X)
  dWLSTM = np.zeros_like(WLSTM)
  dc0 = np.zeros_like(c0)
  dh0 = np.zeros_like(h0)
  dcnext = None
  dhnext = None
  for t in reversed(xrange(n)):
    dht = dH[t].reshape(1, b, d)
    dx, dWLSTMt, dcprev, dhprev = LSTM.backward(dht, caches[t], dcnext, dhnext)
    dhnext = dhprev
    dcnext = dcprev

    dWLSTM += dWLSTMt # accumulate LSTM gradient
    dX[t] = dx[0]
    if t == 0:
      dc0 = dcprev
      dh0 = dhprev

  # and make sure the gradients match
  print 'Making sure batched version agrees with sequential version: (should all be True)'
  print np.allclose(BdX, dX)
  print np.allclose(BdWLSTM, dWLSTM)
  print np.allclose(Bdc0, dc0)
  print np.allclose(Bdh0, dh0)


def checkBatchGradient():
  """ check that the batch gradient is correct """

  # lets gradient check this beast
  n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
  input_size = 10
  WLSTM = LSTM.init(input_size, d) # input size, hidden size
  X = np.random.randn(n,b,input_size)
  h0 = np.random.randn(b,d)
  c0 = np.random.randn(b,d)

  # batch forward backward
  H, Ct, Ht, cache = LSTM.forward(X, WLSTM, c0, h0)
  wrand = np.random.randn(*H.shape)
  loss = np.sum(H * wrand) # weighted sum is a nice hash to use I think
  dH = wrand
  dX, dWLSTM, dc0, dh0 = LSTM.backward(dH, cache)

  def fwd():
    h,_,_,_ = LSTM.forward(X, WLSTM, c0, h0)
    return np.sum(h * wrand)

  # now gradient check all
  delta = 1e-5
  rel_error_thr_warning = 1e-2
  rel_error_thr_error = 1
  tocheck = [X, WLSTM, c0, h0]
  grads_analytic = [dX, dWLSTM, dc0, dh0]
  names = ['X', 'WLSTM', 'c0', 'h0']
  for j in xrange(len(tocheck)):
    mat = tocheck[j]
    dmat = grads_analytic[j]
    name = names[j]
    # gradcheck
    for i in xrange(mat.size):
      old_val = mat.flat[i]
      mat.flat[i] = old_val + delta
      loss0 = fwd()
      mat.flat[i] = old_val - delta
      loss1 = fwd()
      mat.flat[i] = old_val

      grad_analytic = dmat.flat[i]
      grad_numerical = (loss0 - loss1) / (2 * delta)

      if grad_numerical == 0 and grad_analytic == 0:
        rel_error = 0 # both are zero, OK.
        status = 'OK'
      elif abs(grad_numerical) < 1e-7 and abs(grad_analytic) < 1e-7:
        rel_error = 0 # not enough precision to check this
        status = 'VAL SMALL WARNING'
      else:
        rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
        status = 'OK'
        if rel_error > rel_error_thr_warning: status = 'WARNING'
        if rel_error > rel_error_thr_error: status = '!!!!! NOTOK'

      # print stats
      print '%s checking param %s index %s (val = %+8f), analytic = %+8f, numerical = %+8f, relative error = %+8f' \
            % (status, name, `np.unravel_index(i, mat.shape)`, old_val, grad_analytic, grad_numerical, rel_error)


if __name__ == "__main__":
    checkSequentialMatchesBatch()
    input('check OK, press key to continue to gradient check')
    checkBatchGradient()
    print('Making sure batched version agrees with sequential version: (should all be True)')
# Out:
#   File "/tmp/ipython-input-5-2572021927.py", line 196
#     print 'Making sure batched version agrees with sequential version: (should all be True)'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
"""
This is a batched LSTM forward and backward pass
"""
import numpy as np
import code

class LSTM:

  @staticmethod
  def init(input_size, hidden_size, fancy_forget_bias_init = 3):
    """
    Initialize parameters of the LSTM (both weights and biases in one matrix)
    One might way to have a positive fancy_forget_bias_init number (e.g. maybe even up to 5, in some papers)
    """
    # +1 for the biases, which will be the first row of WLSTM
    WLSTM = np.random.randn(input_size + hidden_size + 1, 4 * hidden_size) / np.sqrt(input_size + hidden_size)
    WLSTM[0,:] = 0 # initialize biases to zero
    if fancy_forget_bias_init != 0:
      # forget gates get little bit negative bias initially to encourage them to be turned off
      # remember that due to Xavier initialization above, the raw output activations from gates before
      # nonlinearity are zero mean and on order of standard deviation ~1
      WLSTM[0,hidden_size:2*hidden_size] = fancy_forget_bias_init
    return WLSTM

  @staticmethod
  def forward(X, WLSTM, c0 = None, h0 = None):
    """
    X should be of shape (n,b,input_size), where n = length of sequence, b = batch size
    """
    n,b,input_size = X.shape
    d = WLSTM.shape[1]//4 # hidden size - changed to integer division
    if c0 is None: c0 = np.zeros((b,d))
    if h0 is None: h0 = np.zeros((b,d))

    # Perform the LSTM forward pass with X as the input
    xphpb = WLSTM.shape[0] # x plus h plus bias, lol
    Hin = np.zeros((n, b, xphpb)) # input [1, xt, ht-1] to each tick of the LSTM
    Hout = np.zeros((n, b, d)) # hidden representation of the LSTM (gated cell content)
    IFOG = np.zeros((n, b, d * 4)) # input, forget, output, gate (IFOG)
    IFOGf = np.zeros((n, b, d * 4)) # after nonlinearity
    C = np.zeros((n, b, d)) # cell content
    Ct = np.zeros((n, b, d)) # tanh of cell content
    for t in range(n): # changed from xrange to range
      # concat [x,h] as input to the LSTM
      prevh = Hout[t-1] if t > 0 else h0
      Hin[t,:,0] = 1 # bias
      Hin[t,:,1:input_size+1] = X[t]
      Hin[t,:,input_size+1:] = prevh
      # compute all gate activations. dots: (most work is this line)
      IFOG[t] = Hin[t].dot(WLSTM)
      # non-linearities
      IFOGf[t,:,:3*d] = 1.0/(1.0+np.exp(-IFOG[t,:,:3*d])) # sigmoids; these are the gates
      IFOGf[t,:,3*d:] = np.tanh(IFOG[t,:,3*d:]) # tanh
      # compute the cell activation
      prevc = C[t-1] if t > 0 else c0
      C[t] = IFOGf[t,:,:d] * IFOGf[t,:,3*d:] + IFOGf[t,:,d:2*d] * prevc
      Ct[t] = np.tanh(C[t])
      Hout[t] = IFOGf[t,:,2*d:3*d] * Ct[t]

    cache = {}
    cache['WLSTM'] = WLSTM
    cache['Hout'] = Hout
    cache['IFOGf'] = IFOGf
    cache['IFOG'] = IFOG
    cache['C'] = C
    cache['Ct'] = Ct
    cache['Hin'] = Hin
    cache['c0'] = c0
    cache['h0'] = h0

    # return C[t], as well so we can continue LSTM with prev state init if needed
    return Hout, C[t], Hout[t], cache

  @staticmethod
  def backward(dHout_in, cache, dcn = None, dhn = None):

    WLSTM = cache['WLSTM']
    Hout = cache['Hout']
    IFOGf = cache['IFOGf']
    IFOG = cache['IFOG']
    C = cache['C']
    Ct = cache['Ct']
    Hin = cache['Hin']
    c0 = cache['c0']
    h0 = cache['h0']
    n,b,d = Hout.shape
    input_size = WLSTM.shape[0] - d - 1 # -1 due to bias

    # backprop the LSTM
    dIFOG = np.zeros(IFOG.shape)
    dIFOGf = np.zeros(IFOGf.shape)
    dWLSTM = np.zeros(WLSTM.shape)
    dHin = np.zeros(Hin.shape)
    dC = np.zeros(C.shape)
    dX = np.zeros((n,b,input_size))
    dh0 = np.zeros((b, d))
    dc0 = np.zeros((b, d))
    dHout = dHout_in.copy() # make a copy so we don't have any funny side effects
    if dcn is not None: dC[n-1] += dcn.copy() # carry over gradients from later
    if dhn is not None: dHout[n-1] += dhn.copy()
    for t in reversed(range(n)): # changed from xrange to range

      tanhCt = Ct[t]
      dIFOGf[t,:,2*d:3*d] = tanhCt * dHout[t]
      # backprop tanh non-linearity first then continue backprop
      dC[t] += (1-tanhCt**2) * (IFOGf[t,:,2*d:3*d] * dHout[t])

      if t > 0:
        dIFOGf[t,:,d:2*d] = C[t-1] * dC[t]
        dC[t-1] += IFOGf[t,:,d:2*d] * dC[t]
      else:
        dIFOGf[t,:,d:2*d] = c0 * dC[t]
        dc0 = IFOGf[t,:,d:2*d] * dC[t]
      dIFOGf[t,:,:d] = IFOGf[t,:,3*d:] * dC[t]
      dIFOGf[t,:,3*d:] = IFOGf[t,:,:d] * dC[t]

      # backprop activation functions
      dIFOG[t,:,3*d:] = (1 - IFOGf[t,:,3*d:] ** 2) * dIFOGf[t,:,3*d:]
      y = IFOGf[t,:,:3*d]
      dIFOG[t,:,:3*d] = (y*(1.0-y)) * dIFOGf[t,:,:3*d]

      # backprop matrix multiply
      dWLSTM += np.dot(Hin[t].transpose(), dIFOG[t])
      dHin[t] = dIFOG[t].dot(WLSTM.transpose())

      # backprop the identity transforms into Hin
      dX[t] = dHin[t,:,1:input_size+1]
      if t > 0:
        dHout[t-1,:] += dHin[t,:,input_size+1:]
      else:
        dh0 += dHin[t,:,input_size+1:]

    return dX, dWLSTM, dc0, dh0



# -------------------
# TEST CASES
# -------------------



def checkSequentialMatchesBatch():
  """ check LSTM I/O forward/backward interactions """

  n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
  input_size = 10
  WLSTM = LSTM.init(input_size, d) # input size, hidden size
  X = np.random.randn(n,b,input_size)
  h0 = np.random.randn(b,d)
  c0 = np.random.randn(b,d)

  # sequential forward
  cprev = c0
  hprev = h0
  caches = [{} for t in range(n)] # changed from xrange to range
  Hcat = np.zeros((n,b,d))
  for t in range(n): # changed from xrange to range
    xt = X[t:t+1]
    _, cprev, hprev, cache = LSTM.forward(xt, WLSTM, cprev, hprev)
    caches[t] = cache
    Hcat[t] = hprev

  # sanity check: perform batch forward to check that we get the same thing
  H, _, _, batch_cache = LSTM.forward(X, WLSTM, c0, h0)
  assert np.allclose(H, Hcat), 'Sequential and Batch forward don\'t match!' # fixed string escaping

  # eval loss
  wrand = np.random.randn(*Hcat.shape)
  loss = np.sum(Hcat * wrand)
  dH = wrand

  # get the batched version gradients
  BdX, BdWLSTM, Bdc0, Bdh0 = LSTM.backward(dH, batch_cache)

  # now perform sequential backward
  dX = np.zeros_like(X)
  dWLSTM = np.zeros_like(WLSTM)
  dc0 = np.zeros_like(c0)
  dh0 = np.zeros_like(h0)
  dcnext = None
  dhnext = None
  for t in reversed(range(n)): # changed from xrange to range
    dht = dH[t].reshape(1, b, d)
    dx, dWLSTMt, dcprev, dhprev = LSTM.backward(dht, caches[t], dcnext, dhnext)
    dhnext = dhprev
    dcnext = dcprev

    dWLSTM += dWLSTMt # accumulate LSTM gradient
    dX[t] = dx[0]
    if t == 0:
      dc0 = dcprev
      dh0 = dhprev

  # and make sure the gradients match
  print('Making sure batched version agrees with sequential version: (should all be True)')
  print(np.allclose(BdX, dX))
  print(np.allclose(BdWLSTM, dWLSTM))
  print(np.allclose(Bdc0, dc0))
  print(np.allclose(Bdh0, dh0))


def checkBatchGradient():
  """ check that the batch gradient is correct """

  # lets gradient check this beast
  n,b,d = (5, 3, 4) # sequence length, batch size, hidden size
  input_size = 10
  WLSTM = LSTM.init(input_size, d) # input size, hidden size
  X = np.random.randn(n,b,input_size)
  h0 = np.random.randn(b,d)
  c0 = np.random.randn(b,d)

  # batch forward backward
  H, Ct, Ht, cache = LSTM.forward(X, WLSTM, c0, h0)
  wrand = np.random.randn(*H.shape)
  loss = np.sum(H * wrand) # weighted sum is a nice hash to use I think
  dH = wrand
  dX, dWLSTM, dc0, dh0 = LSTM.backward(dH, cache)

  def fwd():
    h,_,_,_ = LSTM.forward(X, WLSTM, c0, h0)
    return np.sum(h * wrand)

  # now gradient check all
  delta = 1e-5
  rel_error_thr_warning = 1e-2
  rel_error_thr_error = 1
  tocheck = [X, WLSTM, c0, h0]
  grads_analytic = [dX, dWLSTM, dc0, dh0]
  names = ['X', 'WLSTM', 'c0', 'h0']
  for j in range(len(tocheck)): # changed from xrange to range
    mat = tocheck[j]
    dmat = grads_analytic[j]
    name = names[j]
    # gradcheck
    for i in range(mat.size): # changed from xrange to range
      old_val = mat.flat[i]
      mat.flat[i] = old_val + delta
      loss0 = fwd()
      mat.flat[i] = old_val - delta
      loss1 = fwd()
      mat.flat[i] = old_val

      grad_analytic = dmat.flat[i]
      grad_numerical = (loss0 - loss1) / (2 * delta)

      if grad_numerical == 0 and grad_analytic == 0:
        rel_error = 0 # both are zero, OK.
        status = 'OK'
      elif abs(grad_numerical) < 1e-7 and abs(grad_analytic) < 1e-7:
        rel_error = 0 # not enough precision to check this
        status = 'VAL SMALL WARNING'
      else:
        rel_error = abs(grad_analytic - grad_numerical) / abs(grad_numerical + grad_analytic)
        status = 'OK'
        if rel_error > rel_error_thr_warning: status = 'WARNING'
        if rel_error > rel_error_thr_error: status = '!!!!! NOTOK'

      # print stats - fixed string formatting
      print('{} checking param {} index {} (val = {:+8f}), analytic = {:+8f}, numerical = {:+8f}, relative error = {:+8f}'.format(
            status, name, np.unravel_index(i, mat.shape), old_val, grad_analytic, grad_numerical, rel_error))


if __name__ == "__main__":
    checkSequentialMatchesBatch()
    input('check OK, press key to continue to gradient check')
    checkBatchGradient()
    print('Making sure batched version agrees with sequential version: (should all be True)')
# Out:
# Making sure batched version agrees with sequential version: (should all be True)
# True
# True
# True
# True
# check OK, press key to continue to gradient checkhi
# OK checking param X index (np.int64(0), np.int64(0), np.int64(0)) (val = -1.628141), analytic = +0.174810, numerical = +0.174810, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(1)) (val = -1.278094), analytic = -0.109705, numerical = -0.109705, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(2)) (val = -0.019834), analytic = -0.074326, numerical = -0.074326, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(3)) (val = -0.038258), analytic = +0.118806, numerical = +0.118806, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(4)) (val = +1.735691), analytic = -0.016642, numerical = -0.016642, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(5)) (val = -1.236297), analytic = -0.073702, numerical = -0.073702, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(6)) (val = +0.370866), analytic = +0.035642, numerical = +0.035642, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(7)) (val = +0.604558), analytic = +0.066895, numerical = +0.066895, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(8)) (val = -0.392346), analytic = +0.085552, numerical = +0.085552, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(0), np.int64(9)) (val = -0.548576), analytic = +0.036763, numerical = +0.036763, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(0)) (val = -0.234507), analytic = +0.072750, numerical = +0.072750, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(1)) (val = -0.846085), analytic = +0.077309, numerical = +0.077309, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(2)) (val = -0.887799), analytic = -0.062249, numerical = -0.062249, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(3)) (val = +0.669232), analytic = +0.049467, numerical = +0.049467, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(4)) (val = -0.521856), analytic = +0.052203, numerical = +0.052203, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(5)) (val = +2.134156), analytic = +0.060746, numerical = +0.060746, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(6)) (val = +0.785108), analytic = -0.144367, numerical = -0.144367, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(7)) (val = +0.304048), analytic = +0.045854, numerical = +0.045854, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(8)) (val = -0.824458), analytic = +0.060996, numerical = +0.060996, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(1), np.int64(9)) (val = +2.195181), analytic = -0.085403, numerical = -0.085403, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(0)) (val = -1.579628), analytic = +0.080495, numerical = +0.080495, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(1)) (val = -0.083916), analytic = -0.004922, numerical = -0.004922, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(2)) (val = +0.049154), analytic = -0.002823, numerical = -0.002823, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(3)) (val = -1.085467), analytic = +0.046653, numerical = +0.046653, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(4)) (val = -0.928376), analytic = -0.046809, numerical = -0.046809, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(5)) (val = -0.532727), analytic = -0.038993, numerical = -0.038993, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(6)) (val = -0.861021), analytic = +0.104449, numerical = +0.104449, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(7)) (val = -1.600891), analytic = -0.006968, numerical = -0.006968, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(8)) (val = -1.229829), analytic = +0.037828, numerical = +0.037828, relative error = +0.000000
# OK checking param X index (np.int64(0), np.int64(2), np.int64(9)) (val = -0.199575), analytic = +0.015665, numerical = +0.015665, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(0)) (val = -1.273316), analytic = -0.074013, numerical = -0.074013, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(1)) (val = +0.115934), analytic = -0.323334, numerical = -0.323334, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(2)) (val = +0.146476), analytic = +0.265685, numerical = +0.265685, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(3)) (val = -0.603563), analytic = +0.169293, numerical = +0.169293, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(4)) (val = +0.635082), analytic = +0.186331, numerical = +0.186331, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(5)) (val = -1.361420), analytic = -0.225286, numerical = -0.225286, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(6)) (val = +0.225602), analytic = +0.244808, numerical = +0.244808, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(7)) (val = -0.107806), analytic = -0.261096, numerical = -0.261096, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(8)) (val = +0.967798), analytic = +0.100335, numerical = +0.100335, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(0), np.int64(9)) (val = -0.647658), analytic = +0.162874, numerical = +0.162874, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(0)) (val = +1.557401), analytic = +0.114992, numerical = +0.114992, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(1)) (val = +1.046526), analytic = -0.156295, numerical = -0.156295, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(2)) (val = -0.312143), analytic = -0.095864, numerical = -0.095864, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(3)) (val = +0.830656), analytic = +0.112765, numerical = +0.112765, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(4)) (val = -0.594576), analytic = -0.095641, numerical = -0.095641, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(5)) (val = +1.727155), analytic = -0.066682, numerical = -0.066682, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(6)) (val = +0.483609), analytic = +0.060802, numerical = +0.060802, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(7)) (val = +0.390130), analytic = +0.075962, numerical = +0.075962, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(8)) (val = -0.222704), analytic = +0.189693, numerical = +0.189693, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(1), np.int64(9)) (val = -0.430460), analytic = +0.048246, numerical = +0.048246, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(0)) (val = +0.783346), analytic = +0.140766, numerical = +0.140766, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(1)) (val = -2.053295), analytic = +0.080252, numerical = +0.080252, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(2)) (val = -0.846077), analytic = +0.043014, numerical = +0.043014, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(3)) (val = -0.865029), analytic = +0.079512, numerical = +0.079512, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(4)) (val = +0.169133), analytic = -0.107643, numerical = -0.107643, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(5)) (val = -0.911437), analytic = +0.154503, numerical = +0.154503, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(6)) (val = +0.240895), analytic = +0.100556, numerical = +0.100556, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(7)) (val = +0.699532), analytic = -0.164163, numerical = -0.164163, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(8)) (val = +0.517151), analytic = -0.105510, numerical = -0.105510, relative error = +0.000000
# OK checking param X index (np.int64(1), np.int64(2), np.int64(9)) (val = +0.977764), analytic = -0.042208, numerical = -0.042208, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(0)) (val = +0.183934), analytic = -0.300917, numerical = -0.300917, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(1)) (val = +0.032317), analytic = +0.039270, numerical = +0.039270, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(2)) (val = +0.183073), analytic = +0.127268, numerical = +0.127268, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(3)) (val = -0.810174), analytic = -0.192307, numerical = -0.192307, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(4)) (val = -2.089889), analytic = +0.239972, numerical = +0.239972, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(5)) (val = -1.554356), analytic = +0.024571, numerical = +0.024571, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(6)) (val = +0.590055), analytic = +0.060724, numerical = +0.060724, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(7)) (val = +0.337578), analytic = -0.089370, numerical = -0.089370, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(8)) (val = +0.289592), analytic = -0.263489, numerical = -0.263489, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(0), np.int64(9)) (val = -0.744280), analytic = +0.302742, numerical = +0.302742, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(0)) (val = +0.835308), analytic = +0.136010, numerical = +0.136010, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(1)) (val = +1.978970), analytic = +0.072063, numerical = +0.072063, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(2)) (val = -1.545673), analytic = +0.125893, numerical = +0.125893, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(3)) (val = +0.883426), analytic = -0.126035, numerical = -0.126035, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(4)) (val = -1.847670), analytic = +0.140139, numerical = +0.140139, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(5)) (val = -0.569544), analytic = +0.218938, numerical = +0.218938, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(6)) (val = -2.211340), analytic = +0.358066, numerical = +0.358066, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(7)) (val = +1.365075), analytic = -0.167960, numerical = -0.167960, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(8)) (val = +0.205784), analytic = -0.323025, numerical = -0.323025, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(1), np.int64(9)) (val = -0.241449), analytic = +0.096529, numerical = +0.096529, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(0)) (val = -0.072222), analytic = +0.043211, numerical = +0.043211, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(1)) (val = -1.099240), analytic = +0.135445, numerical = +0.135445, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(2)) (val = -0.452790), analytic = +0.202133, numerical = +0.202133, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(3)) (val = -0.413738), analytic = +0.004626, numerical = +0.004626, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(4)) (val = -0.072252), analytic = -0.091631, numerical = -0.091631, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(5)) (val = +0.925156), analytic = +0.018036, numerical = +0.018036, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(6)) (val = +0.198023), analytic = +0.266591, numerical = +0.266591, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(7)) (val = -0.663647), analytic = -0.108178, numerical = -0.108178, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(8)) (val = +0.701218), analytic = -0.145831, numerical = -0.145831, relative error = +0.000000
# OK checking param X index (np.int64(2), np.int64(2), np.int64(9)) (val = -0.899234), analytic = +0.089431, numerical = +0.089431, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(0)) (val = +0.474604), analytic = -0.038386, numerical = -0.038386, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(1)) (val = -0.687702), analytic = +0.113603, numerical = +0.113603, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(2)) (val = -0.931520), analytic = +0.079985, numerical = +0.079985, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(3)) (val = +0.152404), analytic = -0.037195, numerical = -0.037195, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(4)) (val = +0.037422), analytic = +0.131963, numerical = +0.131963, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(5)) (val = -1.466742), analytic = +0.088414, numerical = +0.088414, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(6)) (val = -1.191158), analytic = -0.082488, numerical = -0.082488, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(7)) (val = +2.035905), analytic = -0.123122, numerical = -0.123122, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(8)) (val = -1.269138), analytic = -0.252593, numerical = -0.252593, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(0), np.int64(9)) (val = +1.079787), analytic = -0.006977, numerical = -0.006977, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(0)) (val = +0.085584), analytic = -0.006803, numerical = -0.006803, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(1)) (val = -0.874767), analytic = +0.063437, numerical = +0.063437, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(2)) (val = -0.606043), analytic = +0.028627, numerical = +0.028627, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(3)) (val = -0.768572), analytic = -0.033150, numerical = -0.033150, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(4)) (val = -0.945263), analytic = +0.075404, numerical = +0.075404, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(5)) (val = +0.698363), analytic = -0.007048, numerical = -0.007048, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(6)) (val = -1.010728), analytic = +0.029870, numerical = +0.029870, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(7)) (val = +0.007892), analytic = +0.030380, numerical = +0.030380, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(8)) (val = -0.222793), analytic = -0.044984, numerical = -0.044984, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(1), np.int64(9)) (val = +3.151920), analytic = +0.089794, numerical = +0.089794, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(0)) (val = -0.392866), analytic = +0.042214, numerical = +0.042214, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(1)) (val = +1.154133), analytic = +0.111164, numerical = +0.111164, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(2)) (val = -1.797107), analytic = +0.129020, numerical = +0.129020, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(3)) (val = -0.943342), analytic = +0.051545, numerical = +0.051545, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(4)) (val = +0.295801), analytic = -0.046432, numerical = -0.046432, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(5)) (val = -1.086541), analytic = +0.033643, numerical = +0.033643, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(6)) (val = +1.282663), analytic = +0.161294, numerical = +0.161294, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(7)) (val = -0.919402), analytic = -0.240562, numerical = -0.240562, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(8)) (val = +0.437811), analytic = -0.090502, numerical = -0.090502, relative error = +0.000000
# OK checking param X index (np.int64(3), np.int64(2), np.int64(9)) (val = +0.091526), analytic = +0.033215, numerical = +0.033215, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(0)) (val = -0.691470), analytic = +0.021018, numerical = +0.021018, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(1)) (val = +0.678189), analytic = +0.041862, numerical = +0.041862, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(2)) (val = -0.706119), analytic = -0.024374, numerical = -0.024374, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(3)) (val = +0.812738), analytic = -0.031429, numerical = -0.031429, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(4)) (val = -0.554005), analytic = -0.035157, numerical = -0.035157, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(5)) (val = -0.783207), analytic = -0.008403, numerical = -0.008403, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(6)) (val = +1.907694), analytic = +0.017106, numerical = +0.017106, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(7)) (val = -0.156984), analytic = +0.000644, numerical = +0.000644, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(8)) (val = -0.200744), analytic = -0.067519, numerical = -0.067519, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(0), np.int64(9)) (val = -0.266774), analytic = +0.003103, numerical = +0.003103, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(0)) (val = +1.448314), analytic = +0.006015, numerical = +0.006015, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(1)) (val = -0.135173), analytic = -0.036132, numerical = -0.036132, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(2)) (val = -1.419313), analytic = -0.047295, numerical = -0.047295, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(3)) (val = -0.695517), analytic = +0.012453, numerical = +0.012453, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(4)) (val = +0.482302), analytic = -0.006916, numerical = -0.006916, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(5)) (val = +0.710991), analytic = +0.008460, numerical = +0.008460, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(6)) (val = +0.987404), analytic = -0.045805, numerical = -0.045805, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(7)) (val = +0.543394), analytic = +0.016133, numerical = +0.016133, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(8)) (val = +0.264276), analytic = +0.056117, numerical = +0.056117, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(1), np.int64(9)) (val = -0.294303), analytic = -0.025190, numerical = -0.025190, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(0)) (val = +1.031580), analytic = +0.131408, numerical = +0.131408, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(1)) (val = +0.853934), analytic = +0.106910, numerical = +0.106910, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(2)) (val = -1.273557), analytic = +0.072745, numerical = +0.072745, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(3)) (val = -1.294880), analytic = +0.104582, numerical = +0.104582, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(4)) (val = +0.550787), analytic = -0.087494, numerical = -0.087494, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(5)) (val = -0.375221), analytic = +0.101501, numerical = +0.101501, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(6)) (val = -1.263089), analytic = +0.113185, numerical = +0.113185, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(7)) (val = -0.423703), analytic = -0.165235, numerical = -0.165235, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(8)) (val = -1.003351), analytic = -0.098069, numerical = -0.098069, relative error = +0.000000
# OK checking param X index (np.int64(4), np.int64(2), np.int64(9)) (val = -1.527458), analytic = -0.090820, numerical = -0.090820, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(0)) (val = +0.000000), analytic = -0.151031, numerical = -0.151031, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(1)) (val = +0.000000), analytic = -0.135767, numerical = -0.135767, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(2)) (val = +0.000000), analytic = +0.116055, numerical = +0.116055, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(3)) (val = +0.000000), analytic = -0.181137, numerical = -0.181137, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(4)) (val = +3.000000), analytic = +0.118452, numerical = +0.118452, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(5)) (val = +3.000000), analytic = +0.286757, numerical = +0.286757, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(6)) (val = +3.000000), analytic = -0.002010, numerical = -0.002010, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(7)) (val = +3.000000), analytic = +0.043399, numerical = +0.043399, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(8)) (val = +0.000000), analytic = +0.339840, numerical = +0.339840, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(9)) (val = +0.000000), analytic = -0.640853, numerical = -0.640853, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(10)) (val = +0.000000), analytic = +0.328538, numerical = +0.328538, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(11)) (val = +0.000000), analytic = +0.096167, numerical = +0.096167, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(12)) (val = +0.000000), analytic = -0.514294, numerical = -0.514294, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(13)) (val = +0.000000), analytic = -1.899811, numerical = -1.899811, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(14)) (val = +0.000000), analytic = +0.320693, numerical = +0.320693, relative error = +0.000000
# OK checking param WLSTM index (np.int64(0), np.int64(15)) (val = +0.000000), analytic = +0.632203, numerical = +0.632203, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(0)) (val = +0.699643), analytic = -0.060930, numerical = -0.060930, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(1)) (val = +0.140538), analytic = -0.281491, numerical = -0.281491, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(2)) (val = -0.123056), analytic = +0.092757, numerical = +0.092757, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(3)) (val = +0.276967), analytic = -0.274351, numerical = -0.274351, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(4)) (val = +0.296663), analytic = -0.070634, numerical = -0.070634, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(5)) (val = +0.063890), analytic = +0.225105, numerical = +0.225105, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(6)) (val = +0.058498), analytic = -0.031803, numerical = -0.031803, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(7)) (val = +0.104818), analytic = -0.034923, numerical = -0.034923, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(8)) (val = +0.027319), analytic = +0.142076, numerical = +0.142076, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(9)) (val = -0.124337), analytic = +0.977288, numerical = +0.977288, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(10)) (val = -0.138070), analytic = +0.508459, numerical = +0.508459, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(11)) (val = -0.309532), analytic = -0.318021, numerical = -0.318021, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(12)) (val = -0.028427), analytic = +0.527178, numerical = +0.527178, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(13)) (val = -0.365975), analytic = -0.600874, numerical = -0.600874, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(14)) (val = +0.406747), analytic = -0.005041, numerical = -0.005041, relative error = +0.000000
# OK checking param WLSTM index (np.int64(1), np.int64(15)) (val = -0.283623), analytic = -0.608113, numerical = -0.608113, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(0)) (val = -0.073357), analytic = -0.155744, numerical = -0.155744, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(1)) (val = +0.116664), analytic = -0.151995, numerical = -0.151995, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(2)) (val = +0.183043), analytic = +0.212787, numerical = +0.212787, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(3)) (val = +0.043820), analytic = +0.255282, numerical = +0.255282, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(4)) (val = -0.320304), analytic = -0.015793, numerical = -0.015793, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(5)) (val = -0.501338), analytic = +0.498292, numerical = +0.498292, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(6)) (val = -0.227018), analytic = -0.028695, numerical = -0.028695, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(7)) (val = -0.088422), analytic = -0.011956, numerical = -0.011956, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(8)) (val = -0.070813), analytic = -0.087790, numerical = -0.087790, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(9)) (val = +0.431184), analytic = -0.367181, numerical = -0.367181, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(10)) (val = +0.254498), analytic = +0.158490, numerical = +0.158490, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(11)) (val = +0.023781), analytic = +0.427181, numerical = +0.427181, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(12)) (val = -0.456692), analytic = +0.006040, numerical = +0.006040, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(13)) (val = -0.261554), analytic = -0.515769, numerical = -0.515769, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(14)) (val = +0.100936), analytic = -0.174512, numerical = -0.174512, relative error = +0.000000
# OK checking param WLSTM index (np.int64(2), np.int64(15)) (val = -0.256543), analytic = -0.015838, numerical = -0.015838, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(0)) (val = -0.316916), analytic = +0.014103, numerical = +0.014103, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(1)) (val = +0.093855), analytic = +0.172418, numerical = +0.172418, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(2)) (val = -0.568049), analytic = -0.015123, numerical = -0.015123, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(3)) (val = -0.067527), analytic = -0.006190, numerical = -0.006190, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(4)) (val = -0.306945), analytic = -0.026929, numerical = -0.026929, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(5)) (val = -0.140000), analytic = -0.436885, numerical = -0.436885, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(6)) (val = -0.028866), analytic = +0.009492, numerical = +0.009492, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(7)) (val = -0.167433), analytic = +0.002047, numerical = +0.002047, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(8)) (val = +0.169776), analytic = -0.212163, numerical = -0.212163, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(9)) (val = +0.018837), analytic = -0.470364, numerical = -0.470364, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(10)) (val = -0.019342), analytic = -0.604416, numerical = -0.604416, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(11)) (val = +0.295423), analytic = -0.095223, numerical = -0.095223, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(12)) (val = +0.023012), analytic = +0.080627, numerical = +0.080627, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(13)) (val = -0.318806), analytic = +2.113449, numerical = +2.113449, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(14)) (val = -0.278685), analytic = -0.198454, numerical = -0.198454, relative error = +0.000000
# OK checking param WLSTM index (np.int64(3), np.int64(15)) (val = +0.470705), analytic = +0.175501, numerical = +0.175501, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(0)) (val = +0.038357), analytic = +0.141822, numerical = +0.141822, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(1)) (val = +0.359029), analytic = -0.188721, numerical = -0.188721, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(2)) (val = -0.550181), analytic = -0.022212, numerical = -0.022212, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(3)) (val = +0.325740), analytic = +0.234715, numerical = +0.234715, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(4)) (val = -0.504564), analytic = -0.027647, numerical = -0.027647, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(5)) (val = -0.478588), analytic = +0.204258, numerical = +0.204258, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(6)) (val = -0.517822), analytic = -0.045748, numerical = -0.045748, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(7)) (val = +0.589553), analytic = -0.024263, numerical = -0.024263, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(8)) (val = +0.110569), analytic = +0.005403, numerical = +0.005403, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(9)) (val = -0.181114), analytic = +0.174850, numerical = +0.174850, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(10)) (val = -0.069755), analytic = -0.365471, numerical = -0.365471, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(11)) (val = -0.243501), analytic = +0.355746, numerical = +0.355746, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(12)) (val = +0.159704), analytic = +0.149975, numerical = +0.149975, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(13)) (val = -0.246304), analytic = +0.747479, numerical = +0.747479, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(14)) (val = +0.309523), analytic = +0.411101, numerical = +0.411101, relative error = +0.000000
# OK checking param WLSTM index (np.int64(4), np.int64(15)) (val = +0.134433), analytic = -0.610664, numerical = -0.610664, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(0)) (val = -0.383934), analytic = +0.350882, numerical = +0.350882, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(1)) (val = -0.114289), analytic = +0.268897, numerical = +0.268897, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(2)) (val = +0.175773), analytic = -0.326657, numerical = -0.326657, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(3)) (val = -0.039008), analytic = +0.642059, numerical = +0.642059, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(4)) (val = +0.242786), analytic = -0.003424, numerical = -0.003424, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(5)) (val = +0.570881), analytic = -0.481649, numerical = -0.481649, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(6)) (val = -0.118941), analytic = +0.001651, numerical = +0.001651, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(7)) (val = -0.591251), analytic = -0.016246, numerical = -0.016246, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(8)) (val = -0.213481), analytic = -0.114940, numerical = -0.114940, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(9)) (val = +0.248605), analytic = -0.517076, numerical = -0.517076, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(10)) (val = +0.266272), analytic = -0.524689, numerical = -0.524689, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(11)) (val = +0.120865), analytic = -0.752160, numerical = -0.752160, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(12)) (val = -0.501910), analytic = +0.398291, numerical = +0.398291, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(13)) (val = +0.276625), analytic = +0.780168, numerical = +0.780168, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(14)) (val = +0.355835), analytic = +0.133403, numerical = +0.133403, relative error = +0.000000
# OK checking param WLSTM index (np.int64(5), np.int64(15)) (val = +0.489866), analytic = +0.130495, numerical = +0.130495, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(0)) (val = +0.294137), analytic = +0.234951, numerical = +0.234951, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(1)) (val = -0.502209), analytic = +0.160654, numerical = +0.160654, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(2)) (val = +0.524002), analytic = -0.032782, numerical = -0.032782, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(3)) (val = +0.015938), analytic = +0.465386, numerical = +0.465386, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(4)) (val = -0.049856), analytic = -0.140163, numerical = -0.140163, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(5)) (val = +0.100043), analytic = -0.151480, numerical = -0.151480, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(6)) (val = +0.115526), analytic = -0.044050, numerical = -0.044050, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(7)) (val = -0.201858), analytic = -0.034937, numerical = -0.034937, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(8)) (val = +0.204270), analytic = -0.694925, numerical = -0.694925, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(9)) (val = +0.371792), analytic = +0.701163, numerical = +0.701163, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(10)) (val = +0.074442), analytic = -0.310145, numerical = -0.310145, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(11)) (val = -0.097910), analytic = +0.702410, numerical = +0.702410, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(12)) (val = +0.007277), analytic = +1.350288, numerical = +1.350288, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(13)) (val = -0.197220), analytic = +0.684988, numerical = +0.684988, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(14)) (val = +0.015154), analytic = +0.895683, numerical = +0.895683, relative error = +0.000000
# OK checking param WLSTM index (np.int64(6), np.int64(15)) (val = -0.045511), analytic = -1.357070, numerical = -1.357070, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(0)) (val = -0.206075), analytic = -0.133121, numerical = -0.133121, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(1)) (val = +0.085795), analytic = +0.383997, numerical = +0.383997, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(2)) (val = +0.033695), analytic = +0.014307, numerical = +0.014307, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(3)) (val = -0.155237), analytic = -0.023870, numerical = -0.023870, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(4)) (val = -0.351892), analytic = +0.090278, numerical = +0.090278, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(5)) (val = +0.354689), analytic = -0.583240, numerical = -0.583240, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(6)) (val = +0.246019), analytic = +0.005810, numerical = +0.005810, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(7)) (val = +0.241853), analytic = +0.010374, numerical = +0.010374, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(8)) (val = +0.001681), analytic = +0.076570, numerical = +0.076570, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(9)) (val = -0.431092), analytic = -0.516884, numerical = -0.516884, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(10)) (val = -0.188406), analytic = +0.334132, numerical = +0.334132, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(11)) (val = +0.164511), analytic = -0.037750, numerical = -0.037750, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(12)) (val = +0.061174), analytic = +0.638084, numerical = +0.638084, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(13)) (val = -0.553049), analytic = +1.145640, numerical = +1.145640, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(14)) (val = -0.340529), analytic = +0.145346, numerical = +0.145346, relative error = +0.000000
# OK checking param WLSTM index (np.int64(7), np.int64(15)) (val = +0.028659), analytic = -0.160353, numerical = -0.160353, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(0)) (val = +0.026133), analytic = +0.001857, numerical = +0.001857, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(1)) (val = -0.573513), analytic = -0.451851, numerical = -0.451851, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(2)) (val = +0.409948), analytic = -0.027011, numerical = -0.027011, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(3)) (val = -0.287407), analytic = -0.334993, numerical = -0.334993, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(4)) (val = +0.220806), analytic = +0.040180, numerical = +0.040180, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(5)) (val = -0.251388), analytic = +0.354045, numerical = +0.354045, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(6)) (val = +0.272283), analytic = -0.032109, numerical = -0.032109, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(7)) (val = +0.270092), analytic = -0.009145, numerical = -0.009145, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(8)) (val = -0.436092), analytic = +0.591930, numerical = +0.591930, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(9)) (val = +0.070852), analytic = +0.371107, numerical = +0.371107, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(10)) (val = -0.425716), analytic = +0.037586, numerical = +0.037586, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(11)) (val = +0.059945), analytic = -0.499877, numerical = -0.499877, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(12)) (val = +0.078998), analytic = -0.538549, numerical = -0.538549, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(13)) (val = +0.392751), analytic = -0.064378, numerical = -0.064378, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(14)) (val = +0.267448), analytic = +0.164442, numerical = +0.164442, relative error = +0.000000
# OK checking param WLSTM index (np.int64(8), np.int64(15)) (val = -0.317721), analytic = +0.255395, numerical = +0.255395, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(0)) (val = +0.222367), analytic = -0.066308, numerical = -0.066308, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(1)) (val = +0.289009), analytic = -0.100241, numerical = -0.100241, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(2)) (val = +0.017720), analytic = +0.097621, numerical = +0.097621, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(3)) (val = +0.228738), analytic = +0.246927, numerical = +0.246927, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(4)) (val = +0.095509), analytic = +0.033238, numerical = +0.033238, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(5)) (val = -0.144239), analytic = +0.040810, numerical = +0.040810, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(6)) (val = +0.058333), analytic = -0.000749, numerical = -0.000749, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(7)) (val = -0.077092), analytic = +0.032910, numerical = +0.032910, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(8)) (val = -0.699883), analytic = -0.202301, numerical = -0.202301, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(9)) (val = -0.296788), analytic = -0.647371, numerical = -0.647371, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(10)) (val = +0.074431), analytic = +0.257877, numerical = +0.257877, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(11)) (val = -0.248306), analytic = +0.606038, numerical = +0.606038, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(12)) (val = +0.322759), analytic = +0.125964, numerical = +0.125964, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(13)) (val = +0.331568), analytic = -0.217464, numerical = -0.217464, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(14)) (val = +0.400436), analytic = -0.342019, numerical = -0.342019, relative error = +0.000000
# OK checking param WLSTM index (np.int64(9), np.int64(15)) (val = -0.001142), analytic = +0.518487, numerical = +0.518487, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(0)) (val = -0.245047), analytic = +0.161550, numerical = +0.161550, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(1)) (val = -0.351609), analytic = -0.097730, numerical = -0.097730, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(2)) (val = +0.200552), analytic = -0.172339, numerical = -0.172339, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(3)) (val = -0.629789), analytic = -0.050609, numerical = -0.050609, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(4)) (val = -0.244796), analytic = -0.054798, numerical = -0.054798, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(5)) (val = -0.150225), analytic = -0.047042, numerical = -0.047042, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(6)) (val = +0.204914), analytic = -0.000423, numerical = -0.000423, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(7)) (val = +0.306033), analytic = -0.013242, numerical = -0.013242, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(8)) (val = -0.076107), analytic = +0.051182, numerical = +0.051182, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(9)) (val = -0.291761), analytic = +1.033569, numerical = +1.033569, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(10)) (val = +0.123564), analytic = +0.207400, numerical = +0.207400, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(11)) (val = +0.348547), analytic = +0.120444, numerical = +0.120444, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(12)) (val = -0.146234), analytic = -0.112920, numerical = -0.112920, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(13)) (val = -0.018892), analytic = +0.467874, numerical = +0.467874, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(14)) (val = +0.036747), analytic = +0.513305, numerical = +0.513305, relative error = +0.000000
# OK checking param WLSTM index (np.int64(10), np.int64(15)) (val = +0.168871), analytic = -0.477435, numerical = -0.477435, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(0)) (val = +0.015618), analytic = +0.023086, numerical = +0.023086, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(1)) (val = -0.202108), analytic = +0.069392, numerical = +0.069392, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(2)) (val = -0.104662), analytic = +0.007361, numerical = +0.007361, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(3)) (val = -0.139421), analytic = +0.066673, numerical = +0.066673, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(4)) (val = +0.133444), analytic = -0.043130, numerical = -0.043130, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(5)) (val = +0.383287), analytic = +0.027863, numerical = +0.027863, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(6)) (val = -0.122033), analytic = +0.006446, numerical = +0.006446, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(7)) (val = +0.099324), analytic = -0.004998, numerical = -0.004998, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(8)) (val = +0.026577), analytic = -0.170307, numerical = -0.170307, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(9)) (val = -0.288622), analytic = +0.432037, numerical = +0.432037, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(10)) (val = +0.294147), analytic = +0.249326, numerical = +0.249326, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(11)) (val = -0.043563), analytic = +0.083932, numerical = +0.083932, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(12)) (val = +0.041661), analytic = +0.326236, numerical = +0.326236, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(13)) (val = +0.081302), analytic = -0.506499, numerical = -0.506499, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(14)) (val = +0.094712), analytic = +0.015173, numerical = +0.015173, relative error = +0.000000
# OK checking param WLSTM index (np.int64(11), np.int64(15)) (val = +0.212277), analytic = -0.241785, numerical = -0.241785, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(0)) (val = -0.148735), analytic = -0.057397, numerical = -0.057397, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(1)) (val = -0.033190), analytic = +0.017883, numerical = +0.017883, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(2)) (val = -0.602728), analytic = -0.005040, numerical = -0.005040, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(3)) (val = +0.008522), analytic = -0.109121, numerical = -0.109121, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(4)) (val = +0.543671), analytic = +0.050446, numerical = +0.050446, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(5)) (val = +0.271216), analytic = -0.136698, numerical = -0.136698, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(6)) (val = +0.008369), analytic = +0.007382, numerical = +0.007382, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(7)) (val = -0.041097), analytic = +0.011968, numerical = +0.011968, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(8)) (val = +0.266832), analytic = +0.160535, numerical = +0.160535, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(9)) (val = -0.398189), analytic = -0.515539, numerical = -0.515539, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(10)) (val = +0.203777), analytic = -0.142102, numerical = -0.142102, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(11)) (val = -0.227742), analytic = -0.094016, numerical = -0.094016, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(12)) (val = +0.191296), analytic = -0.341596, numerical = -0.341596, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(13)) (val = +0.183142), analytic = +0.470161, numerical = +0.470161, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(14)) (val = +0.598767), analytic = -0.200360, numerical = -0.200360, relative error = +0.000000
# OK checking param WLSTM index (np.int64(12), np.int64(15)) (val = -0.083927), analytic = +0.349640, numerical = +0.349640, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(0)) (val = -0.046747), analytic = +0.059483, numerical = +0.059483, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(1)) (val = -0.048042), analytic = +0.023716, numerical = +0.023716, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(2)) (val = -0.034084), analytic = -0.035331, numerical = -0.035331, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(3)) (val = +0.006657), analytic = +0.036363, numerical = +0.036363, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(4)) (val = -0.255519), analytic = +0.001310, numerical = +0.001310, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(5)) (val = +0.042635), analytic = -0.050615, numerical = -0.050615, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(6)) (val = -0.104065), analytic = -0.004644, numerical = -0.004644, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(7)) (val = -0.176238), analytic = -0.005445, numerical = -0.005445, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(8)) (val = -0.594506), analytic = -0.043443, numerical = -0.043443, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(9)) (val = -0.113600), analytic = -0.144249, numerical = -0.144249, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(10)) (val = -0.023746), analytic = -0.324108, numerical = -0.324108, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(11)) (val = +0.056382), analytic = -0.004275, numerical = -0.004275, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(12)) (val = -0.163507), analytic = -0.047930, numerical = -0.047930, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(13)) (val = +0.644514), analytic = +0.626983, numerical = +0.626983, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(14)) (val = +0.098978), analytic = +0.281461, numerical = +0.281461, relative error = +0.000000
# OK checking param WLSTM index (np.int64(13), np.int64(15)) (val = +0.346592), analytic = -0.142551, numerical = -0.142551, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(0)) (val = +0.144465), analytic = -0.046671, numerical = -0.046671, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(1)) (val = -0.263310), analytic = -0.072016, numerical = -0.072016, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(2)) (val = -0.338361), analytic = +0.003577, numerical = +0.003577, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(3)) (val = -0.087636), analytic = -0.044511, numerical = -0.044511, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(4)) (val = -0.104117), analytic = +0.030247, numerical = +0.030247, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(5)) (val = +0.318703), analytic = -0.057843, numerical = -0.057843, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(6)) (val = +0.274516), analytic = -0.015855, numerical = -0.015855, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(7)) (val = +0.215409), analytic = -0.002465, numerical = -0.002465, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(8)) (val = -0.078800), analytic = +0.132330, numerical = +0.132330, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(9)) (val = +0.071075), analytic = -0.369946, numerical = -0.369946, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(10)) (val = +0.458399), analytic = -0.188843, numerical = -0.188843, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(11)) (val = -0.143044), analytic = +0.008320, numerical = +0.008320, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(12)) (val = +0.025021), analytic = -0.163864, numerical = -0.163864, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(13)) (val = +0.752803), analytic = +0.862620, numerical = +0.862620, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(14)) (val = -0.312594), analytic = -0.085399, numerical = -0.085399, relative error = +0.000000
# OK checking param WLSTM index (np.int64(14), np.int64(15)) (val = +0.163313), analytic = +0.187520, numerical = +0.187520, relative error = +0.000000
# OK checking param c0 index (np.int64(0), np.int64(0)) (val = -1.266599), analytic = -0.765752, numerical = -0.765752, relative error = +0.000000
# OK checking param c0 index (np.int64(0), np.int64(1)) (val = +1.230695), analytic = -0.095839, numerical = -0.095839, relative error = +0.000000
# OK checking param c0 index (np.int64(0), np.int64(2)) (val = -0.288011), analytic = +0.590908, numerical = +0.590908, relative error = +0.000000
# OK checking param c0 index (np.int64(0), np.int64(3)) (val = -0.208141), analytic = -0.001535, numerical = -0.001535, relative error = +0.000000
# OK checking param c0 index (np.int64(1), np.int64(0)) (val = +0.157907), analytic = +0.161118, numerical = +0.161118, relative error = +0.000000
# OK checking param c0 index (np.int64(1), np.int64(1)) (val = -0.445844), analytic = -0.364478, numerical = -0.364478, relative error = +0.000000
# OK checking param c0 index (np.int64(1), np.int64(2)) (val = -0.395188), analytic = +0.268373, numerical = +0.268373, relative error = +0.000000
# OK checking param c0 index (np.int64(1), np.int64(3)) (val = +0.054591), analytic = -0.266337, numerical = -0.266337, relative error = +0.000000
# OK checking param c0 index (np.int64(2), np.int64(0)) (val = +0.596335), analytic = -0.291521, numerical = -0.291521, relative error = +0.000000
# OK checking param c0 index (np.int64(2), np.int64(1)) (val = +0.019160), analytic = -0.196864, numerical = -0.196864, relative error = +0.000000
# OK checking param c0 index (np.int64(2), np.int64(2)) (val = -2.206527), analytic = -0.040810, numerical = -0.040810, relative error = +0.000000
# OK checking param c0 index (np.int64(2), np.int64(3)) (val = -2.391191), analytic = -0.005439, numerical = -0.005439, relative error = +0.000000
# OK checking param h0 index (np.int64(0), np.int64(0)) (val = -0.905439), analytic = +0.060913, numerical = +0.060913, relative error = +0.000000
# OK checking param h0 index (np.int64(0), np.int64(1)) (val = +0.708063), analytic = +0.227670, numerical = +0.227670, relative error = +0.000000
# OK checking param h0 index (np.int64(0), np.int64(2)) (val = +0.778798), analytic = +0.013128, numerical = +0.013128, relative error = +0.000000
# OK checking param h0 index (np.int64(0), np.int64(3)) (val = +0.606454), analytic = -0.132577, numerical = -0.132577, relative error = +0.000000
# OK checking param h0 index (np.int64(1), np.int64(0)) (val = +0.716756), analytic = -0.036671, numerical = -0.036671, relative error = +0.000000
# OK checking param h0 index (np.int64(1), np.int64(1)) (val = -1.075869), analytic = +0.079912, numerical = +0.079912, relative error = +0.000000
# OK checking param h0 index (np.int64(1), np.int64(2)) (val = +0.441139), analytic = -0.046281, numerical = -0.046281, relative error = +0.000000
# OK checking param h0 index (np.int64(1), np.int64(3)) (val = -1.084667), analytic = -0.051871, numerical = -0.051871, relative error = +0.000000
# OK checking param h0 index (np.int64(2), np.int64(0)) (val = +0.477932), analytic = -0.007745, numerical = -0.007745, relative error = +0.000000
# OK checking param h0 index (np.int64(2), np.int64(1)) (val = -0.262942), analytic = -0.020609, numerical = -0.020609, relative error = +0.000000
# OK checking param h0 index (np.int64(2), np.int64(2)) (val = +0.447378), analytic = -0.003443, numerical = -0.003443, relative error = +0.000000
# OK checking param h0 index (np.int64(2), np.int64(3)) (val = -1.459991), analytic = -0.100537, numerical = -0.100537, relative error = +0.000000
# Making sure batched version agrees with sequential version: (should all be True)
